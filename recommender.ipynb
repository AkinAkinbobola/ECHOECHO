# %%
import librosa
import numpy as np
import pandas as pd
import numpy
import matplotlib.pylab as plt
import seaborn as sns
from glob import glob
import librosa.display
import IPython.display as ipd
from itertools import cycle

# %%
sns.set_theme(style="white", palette=None)
color_pal = plt.rcParams["axes.prop_cycle"].by_key()["color"]
color_cycle = cycle(plt.rcParams["axes.prop_cycle"].by_key()["color"])

# %%
audio_files = glob('music_dir/*.wav')

# %%
# ipd.Audio(audio_files[0])

# %%
y, sr = librosa.load(audio_files[0])
print(f'Y: {y[:10]}')
print(f'Shape Y: {y.shape}')
print(f'sr: {sr}')
# Out:
# Y: [-4.9548485e-06  6.9629205e-06 -7.3501456e-06  2.0751961e-06
#   5.3365688e-06 -6.7374840e-06  7.3006740e-06 -3.0420306e-06
#  -3.2033324e-06  1.5381670e-07]
# Shape Y: (4484160,)
# sr: 22050

# %%
pd.Series(y).plot(figsize=(10, 5), lw=1, title="Raw Audio Data Example")
plt.show()

# %%
D = librosa.stft(y)

# %%
S_db = librosa.amplitude_to_db(np.absolute(D), ref=np.max)
S_db.shape
# Out:
# (1025, 8759)

# %%
fig, ax = plt.subplots(figsize=(10, 5))
img = librosa.display.specshow(S_db, x_axis="time", y_axis="log", ax=ax)
fig.colorbar(img, ax=ax, format=f'%0.2f')
plt.show()
